# %%
import numpy as np
import pandas as pd
import math
import os

# Set display options
pd.set_option('display.precision', 6)
pd.set_option('display.width', 1000)

# %% [markdown]
# # Simpson method

# %% [markdown]
# ## Algorithm

# %% [markdown]
# * Input
#     1.  **Function**: $f(x)$ defined and continuous on $[a, b]$.
#     2.  **Interval**: $[a, b]$.
#     3.  **Error Tolerance**: $\epsilon$ (maximum allowable error).
#
# * Steps
#
# **1. Determine Number of Sub-intervals ($n$)**
#    * Calculate the maximum absolute value of the fourth derivative on the interval:
#        $$M_4 = \max_{x \in [a,b]} |f^{(4)}(x)|$$
#    * Using the error bound formula $|E| \le \frac{M_4 (b-a)^5}{180 n^4}$, solve for the minimum integer $n$ such that the error is less than $\epsilon$:
#        $$n > \sqrt[4]{\frac{M_4 (b-a)^5}{180 \epsilon}}$$
#    * **Constraint**: $n$ must be an **even integer**.
#    * Set $n = \lceil \text{calculated value} \rceil$. If $n$ is odd, $n = n + 1$.
#
# **2. Define Step Size ($h$)**
#    * Calculate the width of each sub-interval:
#        $$h = \frac{b - a}{n}$$
#
# **3. Discretization**
#    * Generate $n+1$ points ($x_k$) and their corresponding function values ($y_k$):
#        For $k = 0, 1, \dots, n$:
#        $$x_k = a + k \cdot h$$
#        $$y_k = f(x_k)$$
#
# **4. Compute Integral Approximation**
#    * Apply Simpson's 1/3 formula:
#        $$I \approx \frac{h}{3} \left[ y_0 + y_n + 4 \sum_{k \text{ odd}} y_k + 2 \sum_{k \text{ even}} y_k \right]$$
#      (Sum odd indices $1, 3, \dots, n-1$ multiplied by 4; Sum even indices $2, 4, \dots, n-2$ multiplied by 2).
#
# * Output
#     * **Approximate Integral**: $I \approx \int_a^b f(x) \, dx$

# %%
# Cell 2: Helper to estimate Max 4th Derivative (M4)
def get_m4_max_abs_fourth_derivative(func_d4, a, b, num_samples=1000):
    """
    Estimates M4 = max|f''''(x)| on [a, b] by sampling.
    Needed for Simpson's Rule error estimation.
    """
    x_test = np.linspace(a, b, num_samples)
    y_test = np.abs(func_d4(x_test))
    return np.max(y_test)

# %%
# Cell 4: Calculation of n (loopTimes)
def loopTimes_simpson(f, d4f, a, b, eps):
    # Step 1: Calculate M4
    M4 = get_m4_max_abs_fourth_derivative(d4f, a, b)

    # Step 2: Determine number of segments n
    # Error <= (M4 * (b-a)^5) / (180 * n^4) < eps
    # n > [ (M4 * (b-a)^5) / (180 * eps) ] ^ (1/4)
    numerator = M4 * (b - a)**5
    denominator = 180 * eps
    n_float = (numerator / denominator)**0.25
    
    n = math.ceil(n_float)
    
    # Simpson's rule requires n to be EVEN
    if n % 2 != 0:
        n += 1

    return numerator, denominator, n_float, n

# %%
# Cell 5: Solve Function
def solve_simpson(f, d4f, a, b, eps):
    M4 = get_m4_max_abs_fourth_derivative(d4f, a, b)
    numerator, denominator, n_float, n = loopTimes_simpson(f, d4f, a, b, eps)
    h = (b - a) / n

    # Step 4: Generate points x_k and values y_k
    x_values = np.linspace(a, b, n + 1)
    y_values = f(x_values)

    # Display Table using Pandas
    data = {
        'k': range(n + 1),
        'x_k': x_values,
        'y_k': y_values
    }
    df = pd.DataFrame(data)

    # Step 5: Apply Simpson's Formula
    # I = h/3 * [y0 + yn + 4*Odd_Sum + 2*Even_Sum]
    
    y_start = y_values[0]
    y_end = y_values[-1]
    
    # Odd indices: 1, 3, 5, ..., n-1
    sum_odd = np.sum(y_values[1:n:2])
    
    # Even indices: 2, 4, 6, ..., n-2 (exclude 0 and n)
    sum_even = np.sum(y_values[2:n-1:2])
    
    I = (h / 3) * (y_start + y_end + 4 * sum_odd + 2 * sum_even)
    
    return df, I

# %% [markdown]
# ## Result

# %%
# Cell 7: Define Problem (Using the same example: 1/(x^2+1))
f = lambda x: 1/(x**2+1)

# 4th derivative of 1/(x^2+1)
# Derived as: 24(5x^4 - 10x^2 + 1) / (x^2+1)^5
d4f = lambda x: (24 * (5*x**4 - 10*x**2 + 1)) / ((x**2 + 1)**5)

a = 0.0       # Start of interval
b = 2.0       # End of interval
eps = 1e-6    # Desired maximum error

print(f"--- Simpson's 1/3 Rule Calculation ---")
print(f"Goal: Integrate f(x) on [{a}, {b}] with error < {eps}\n")
# Out:
# --- Simpson's 1/3 Rule Calculation ---
# Goal: Integrate f(x) on [0.0, 2.0] with error < 1e-06

# %%
# Cell 8: Step 1 Output
M4 = get_m4_max_abs_fourth_derivative(d4f, a, b)
print(f"Step 1: Estimate max|f''''(x)| (M4)")
print(f"M4 ≈ {M4:.6f}")
# Out:
# Step 1: Estimate max|f''''(x)| (M4)
# M4 ≈ 24.000000

# %%
# Cell 9: Step 2 Output
numerator, denominator, n_float, n = loopTimes_simpson(f, d4f, a, b, eps)
print(f"\nStep 2: Calculate minimum n (must be even)")
print(f"n > ({numerator:.6f} / {denominator:.6f})^(1/4) = {n_float:.6f}")
print(f"Chosen n = {n}")
# Out:
# Step 2: Calculate minimum n (must be even)
# n > (768.000000 / 0.000180)^(1/4) = 45.448775
# Chosen n = 46

# %%
# Cell 10: Step 3 Output
h = (b - a) / n
print(f"\nStep 3: Calculate step size h")
print(f"h = ({b} - {a}) / {n} = {h:.6f}")
# Out:
# Step 3: Calculate step size h
# h = (2.0 - 0.0) / 46 = 0.043478

# %%
# Cell 11: Step 4 Output (Table)
df, I = solve_simpson(f, d4f, a, b, eps)
print(f"\nStep 4: Table of values (x_k, y_k)")
df
# Out:
# Step 4: Table of values (x_k, y_k)
#      k       x_k       y_k
# 0    0  0.000000  1.000000
# 1    1  0.043478  0.998113
# 2    2  0.086957  0.992495
# 3    3  0.130435  0.983271
# 4    4  0.173913  0.970642
# 5    5  0.217391  0.954874
# 6    6  0.260870  0.936283
# 7    7  0.304348  0.915225
# 8    8  0.347826  0.892074
# 9    9  0.391304  0.867213
# 10  10  0.434783  0.841017
# 11  11  0.478261  0.813846
# 12  12  0.521739  0.786033
# 13  13  0.565217  0.757880
# 14  14  0.608696  0.729655
# 15  15  0.652174  0.701592
# 16  16  0.695652  0.673885
# 17  17  0.739130  0.646699
# 18  18  0.782609  0.620164
# 19  19  0.826087  0.594382
# 20  20  0.869565  0.569429
# 21  21  0.913043  0.545361
# 22  22  0.956522  0.522211
# 23  23  1.000000  0.500000
# 24  24  1.043478  0.478733
# 25  25  1.086957  0.458406
# 26  26  1.130435  0.439004
# 27  27  1.173913  0.420509
# 28  28  1.217391  0.402894
# 29  29  1.260870  0.386131
# 30  30  1.304348  0.370189
# 31  31  1.347826  0.355034
# ...

# %%
# Cell 12: Step 5 Output (Final)
print(f"\nStep 5: Final Calculation")
print(f"Approximate Integral I = {I:.8f}")
# Out:
# Step 5: Final Calculation
# Approximate Integral I = 1.10714871

# %% [markdown]
# # Runga-Principle estimate

# %% [markdown]
# ## Algorithm

# %%
def solve_adaptive_simpson_runge(f, a, b, eps):
    """
    Adaptive Simpson's 1/3 Rule using Runge's Principle for termination.
    
    Args:
        f (function): Function to integrate.
        a (float): Start of interval.
        b (float): End of interval.
        eps (float): Error tolerance.
        
    Returns:
        float: Approximate Integral (Richardson Improved).
        pd.DataFrame: History of iterations.
    """
    history = []
    
    # --- Step 1: Initialization (Loose Grid: n=2) ---
    # Simpson requires even intervals. Minimum is n=2 (3 points).
    n_loose = 2
    h_loose = (b - a) / 2
    
    # Points: a, mid, b
    mid_point = (a + b) / 2
    y_a = f(a)
    y_b = f(b)
    y_mid = f(mid_point)
    
    # Keep track of the sum of internal points for efficient updating
    # For n=2, the only internal point is 'mid'
    sum_internal_points = y_mid 
    
    # Simpson Formula: h/3 * (y_a + y_b + 4*Sum_New_Internal + 2*Sum_Old_Internal)
    # For initial step n=2: Old_Internal is empty (0), New is y_mid
    I_loose = (h_loose / 3) * (y_a + y_b + 4 * sum_internal_points)
    
    history.append({
        'Iteration': 0,
        'n': n_loose,
        'h': h_loose,
        'Integral': I_loose,
        'Error Est': np.nan
    })
    
    iteration = 1
    print(f"Start: n={n_loose}, I={I_loose:.6f}")
    
    # --- Step 2: Loop (Dense Grid Refinement) ---
    while True:
        # 2a. Shrink step h to 1/2 original
        n_dense = n_loose * 2
        h_dense = h_loose / 2
        
        # 2b. Generate NEW points (Odd indices in the new grid)
        # x_new = a + (2k - 1) * h_dense
        k_values = np.arange(1, n_loose + 1)
        x_new_points = a + (2 * k_values - 1) * h_dense
        
        # Calculate sum of new points
        current_new_sum = np.sum(f(x_new_points))
        
        # 2c. Calculate I_dense using Optimized Formula
        # In the new grid:
        # - Endpoints (y_a, y_b) -> Weight 1
        # - ALL Previous Internal Points -> Weight 2 (They become even indices)
        # - ALL New Points -> Weight 4 (They are the odd indices)
        I_dense = (h_dense / 3) * (y_a + y_b + 2 * sum_internal_points + 4 * current_new_sum)
        
        # 2d. Calculate Error using Runge's Principle (p=4 -> Divisor 15)
        error_est = abs(I_dense - I_loose) / 15.0
        
        history.append({
            'Iteration': iteration,
            'n': n_dense,
            'h': h_dense,
            'Integral': I_dense,
            'Error Est': error_est
        })
        
        # 2e. Check Condition
        if error_est < eps:
            print(f"Stop: Converged at Iteration {iteration} (Error {error_est:.2e} < {eps})")
            
            # Richardson Improvement for Simpson
            I_improved = I_dense + error_est
            return I_improved, pd.DataFrame(history)
        
        # Prepare for next loop
        # The "New" points from this step become part of the "Internal" points for the next step
        sum_internal_points += current_new_sum
        
        n_loose = n_dense
        h_loose = h_dense
        I_loose = I_dense
        iteration += 1
        
        if iteration > 25: 
            print("Warning: Max iterations reached without convergence.")
            return I_dense, pd.DataFrame(history)

# %% [markdown]
# ## Result

# %%
# Function: f(x) = 1 / (x^2 + 1)
# Exact Integral from 0 to 2 is arctan(2) ≈ 1.10714872
f_func = lambda x: 1 / (x**2 + 1)
a_val = 0.0
b_val = 2.0
epsilon = 1e-6

# %%
print(f"--- Adaptive Simpson's Rule (Runge Method) ---")
print(f"Goal: Integrate 1/(x^2+1) on [0, 2] with eps < {epsilon}\n")

final_I, df_history = solve_adaptive_simpson_runge(f_func, a_val, b_val, epsilon)

print("\n--- Iteration History ---")
df_history
# Out:
# --- Adaptive Simpson's Rule (Runge Method) ---
# Goal: Integrate 1/(x^2+1) on [0, 2] with eps < 1e-06
#
# Start: n=2, I=1.066667
# Stop: Converged at Iteration 3 (Error 5.52e-07 < 1e-06)
#
# --- Iteration History ---
#    Iteration   n      h  Integral     Error Est
# 0          0   2  1.000  1.066667           NaN
# 1          1   4  0.500  1.105128  2.564103e-03
# 2          2   8  0.250  1.107140  1.341279e-04
# 3          3  16  0.125  1.107148  5.521206e-07

# %%
print("\n--- Final Result ---")
print(f"Approximate Integral (Richardson Improved): {final_I:.9f}")
# Out:
# --- Final Result ---
# Approximate Integral (Richardson Improved): 1.107148958

# %% [markdown]
# # No-function variant

# %% [markdown]
# ## Algorithm

# %%
# --- 1. Helper: Simpson's 1/3 Rule Calculation ---
def simpson_rule_data(x, y):
    """
    Calculates Simpson's 1/3 integral for a set of points.
    Requires an EVEN number of intervals (ODD number of points).
    """
    n = len(x) - 1
    if n == 0: return 0.0
    if n % 2 != 0:
        raise ValueError(f"Simpson's Rule requires an EVEN number of intervals. Current n={n}.")
        
    h = (x[-1] - x[0]) / n
    
    # Formula: h/3 * [y0 + yn + 4*Sum(Odd) + 2*Sum(Even)]
    # Odd indices: 1, 3, ..., n-1
    sum_odd = np.sum(y[1:n:2])
    
    # Even indices: 2, 4, ..., n-2
    sum_even = np.sum(y[2:n:2])
    
    I = (h / 3) * (y[0] + y[-1] + 4 * sum_odd + 2 * sum_even)
    return I

# %%
def solve_runge_simpson(x_vals, y_vals):
    x = np.array(x_vals)
    y = np.array(y_vals)
    n = len(x) - 1
    
    # 1. Initial Check: Is fine grid valid for Simpson?
    if n % 2 != 0:
        return {
            "I_h": None, "Error_Est": None, 
            "Note": f"Cannot apply Simpson's. Total intervals n={n} is ODD."
        }
        
    # 2. Find valid Stride k
    # We need a k where n is divisible by k AND (n/k) is still even.
    k_stride = None
    
    limit = int(n**0.5) + 1
    for i in range(2, limit + 1):
        if n % i == 0:
            # Candidate found. Check if coarse grid will have even intervals.
            intervals_coarse = n // i
            if intervals_coarse % 2 == 0:
                k_stride = i
                break
                
    # Edge Case: If no small divisor found, maybe we can jump by a larger factor?
    # Or simply, if n=4, k=2 works. The loop covers it.
    
    if k_stride is None:
        # Fallback: Calculate Fine Integral only
        try:
            val = simpson_rule_data(x, y)
            return {"I_h": val, "Error_Est": None, "Note": "Valid k not found for Runge (Coarse grid would be odd)."}
        except:
             return {"I_h": None, "Error_Est": None, "Note": "Error in calculation."}

    # 3. Runge Logic
    # Fine Grid
    I_h = simpson_rule_data(x, y)
    
    # Coarse Grid
    I_kh = simpson_rule_data(x[::k_stride], y[::k_stride])
    
    # Error Estimate (p=4 for Simpson)
    p = 4
    denominator = (k_stride ** p) - 1  # e.g., 2^4 - 1 = 15
    
    error = abs(I_h - I_kh) / denominator
    I_improved = I_h + (I_h - I_kh) / denominator
    
    return {
        "I_h": I_h, 
        "I_kh": I_kh, 
        "Error_Est": error, 
        "I_improved": I_improved, 
        "k_stride": k_stride
    }

# %%
# --- 3. Main Function: Wrapper for Composite Function ---
def solve_functional_simpson_tuples(points_list, functional_func):
    """
    Integrates g(f(x)) using Simpson's Rule + Runge's Principle.
    """
    # Unzip data
    x_vals, y_vals = zip(*points_list)
    x = np.array(x_vals)
    y_original = np.array(y_vals)
    
    # Apply Transformation: g(x, f(x))
    try:
        y_transformed = functional_func(x, y_original)
    except:
        y_transformed = np.array([functional_func(xi, yi) for xi, yi in zip(x, y_original)])
    
    # Print Table
    df = pd.DataFrame({
        'x': x,
        'Original f(x)': y_original,
        'Transformed g(x, f(x))': y_transformed
    })
    
    # Solve
    result = solve_runge_simpson(x, y_transformed)
    
    return df, result

# %% [markdown]
# ## Result

# %%
#Reading file

def parse_xy_data(filepath, delimiter=None):
    """
    Reads a CSV-like file with x, y data and returns a list of (x, y) tuples.

    This function is designed to handle different delimiters (like ';' or ' ')
    and assumes that commas (',') are used as decimal separators, based on
    the provided image.

    Args:
        filepath (str): The path to the data file.
        delimiter (str, optional): The column delimiter (e.g., ';', ' '). 
                                   If None, the function will try to 
                                   auto-detect it.

    Returns:
        list: A list of (x, y) float tuples.
              Returns an empty list if the file cannot be read or is empty.
    """
    data_points = []
    detected_delimiter = delimiter
    
    # --- 1. Delimiter Sniffing (if not provided) ---
    if detected_delimiter is None:
        try:
            with open(filepath, 'r', encoding='utf-8') as f:
                # Read the first non-empty line to guess
                first_line = ""
                for line in f:
                    first_line = line.strip()
                    if first_line:
                        break
                
                if ';' in first_line:
                    detected_delimiter = ';'
                elif ' ' in first_line:
                    # Check if it's likely a space delimiter
                    parts = re.split(r'\s+', first_line)
                    if len(parts) == 2:
                        try:
                            # Try to parse to see if it makes sense
                            float(parts[0].replace(',', '.'))
                            float(parts[1].replace(',', '.'))
                            detected_delimiter = ' '
                        except (ValueError, IndexError):
                             # Not a valid 2-column space-delimited float line
                             pass
                
                if detected_delimiter is None and ',' in first_line:
                    # Comma is the last guess, as it's ambiguous with decimal
                    detected_delimiter = ','
                
                if detected_delimiter is None:
                    # Final fallback based on your image
                    print("Warning: Could not auto-detect delimiter. Falling back to ';'.")
                    detected_delimiter = ';'
        except Exception as e:
            print(f"Error opening/reading file for sniffing: {e}")
            return [] # Return empty list on error
    
    print(f"Using delimiter: '{detected_delimiter}'")

    # --- 2. File Parsing ---
    try:
        with open(filepath, 'r', encoding='utf-8') as f:
            for line_number, line in enumerate(f, 1):
                line = line.strip()
                if not line or line.startswith('#'):
                    continue # Skip empty lines or comment lines

                # Split the line by the detected delimiter
                if detected_delimiter == ' ':
                    # Use regex split for spaces to handle multiple spaces
                    parts = re.split(r'\s+', line)
                else:
                    parts = line.split(detected_delimiter)

                # Ensure we have exactly two columns
                if len(parts) == 2:
                    x_str, y_str = parts
                    
                    try:
                        # KEY STEP: Replace comma with dot for float conversion
                        x_val = float(x_str.strip().replace(',', '.'))
                        y_val = float(y_str.strip().replace(',', '.'))
                        data_points.append((x_val, y_val))
                    except ValueError as e:
                        # Warn if conversion to float fails
                        print(f"Warning: Could not parse numbers on line {line_number}: '{line}'. Error: {e}")
                else:
                    # Warn if the line doesn't have exactly two parts
                    print(f"Warning: Skipping malformed line {line_number}: '{line}'. Expected 2 columns, found {len(parts)}")
    
    except FileNotFoundError:
        print(f"Error: File not found at '{filepath}'")
        return []
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
        return []

    return data_points

# %%
print("--- Example: Reading '19data.csv' ---")
    
# You would replace '19data.csv' with the path to your actual file
file_to_read = '19data.csv' 
    
# Check if the file exists before trying to read it
if os.path.exists(file_to_read):
    # Call the function to parse the file.
    # It will try to auto-detect the delimiter.
    all_points = parse_xy_data(file_to_read)
        
    if all_points:
        print(f"Successfully parsed {len(all_points)} data points:")
        df_input = pd.DataFrame(all_points, columns=['x', 'y'])
        print(df_input.to_string(index=False))
    else:
        print(f"Could not parse any data points from '{file_to_read}'.")
        print("Please check the file format and warnings above.")
            
else:
    print(f"Error: The file '{file_to_read}' was not found.")
    print("Please create this file or change 'file_to_read' variable")
    print("to point to your existing data file.")
# Out:
# --- Example: Reading '19data.csv' ---
# Using delimiter: ';'
# Successfully parsed 141 data points:
#    x         y
#  1.0  1.888165
#  1.1  2.040674
#  1.2  2.183783
#  1.3  2.317062
#  1.4  2.440180
#  1.5  2.552904
#  1.6  2.655108
#  1.7  2.746770
#  1.8  2.827973
#  1.9  2.898905
#  2.0  2.959856
#  2.1  3.011216
#  2.2  3.053472
#  2.3  3.087200
#  2.4  3.113063
#  2.5  3.131801
#  2.6  3.144226
#  2.7  3.151214
#  2.8  3.153693
#  2.9  3.152638
#  3.0  3.149059
#  3.1  3.143991
#  3.2  3.138483
#  3.3  3.133589
#  3.4  3.130359
#  3.5  3.129822
#  3.6  3.132985
#  3.7  3.140813
#  3.8  3.154229
#  3.9  3.174097
#  4.0  3.201218
#  4.1  3.236321
#  4.2  3.280052
#  4.3  3.332976
#  4.4  3.395562
#  4.5  3.468184
#  4.6  3.551115
#  4.7  3.644527
#  4.8  3.748484
#  4.9  3.862948
#  5.0  3.987774
#  5.1  4.122713
#  5.2  4.267418
#  5.3  4.421440
#  5.4  4.584241
#  5.5  4.755192
#  5.6  4.933585
#  5.7  5.118637
#  5.8  5.309498
#  5.9  5.505260
#  6.0  5.704965
# ...

# %%
# 1. Prepare Data as List of Tuples
# Imagine this comes from reading a file row by row
subset_points = [
        (x, y) for (x, y) in all_points 
        if 1 <= x <= 7
]

# 2. Define Function g(x, f(x))
# Example: Integrate x * f(x) + sqrt(x)
my_func = lambda x, y: x * y + np.sqrt(x)

# %%
# 3. Calculate
df, res = solve_functional_simpson_tuples(subset_points, my_func)
df
# Out:
#       x  Original f(x)  Transformed g(x, f(x))
# 0   1.0       1.888165                2.888165
# 1   1.1       2.040674                3.293550
# 2   1.2       2.183783                3.715984
# 3   1.3       2.317062                4.152357
# 4   1.4       2.440180                4.599468
# ..  ...            ...                     ...
# 56  6.6       6.928754               48.298824
# 57  6.7       7.127250               50.341011
# 58  6.8       7.321477               52.393726
# 59  6.9       7.510494               54.449192
# 60  7.0       7.693410               56.499625
#
# [61 rows x 3 columns]

# %%
print("\n--- Final Results ---")
if res['I_h'] is not None:
    print(f"Integral (I_h):      {res['I_h']:.6f}")
    
    if res['Error_Est'] is not None:
        print(f"Coarse Integral (I_kh): {res['I_kh']:.6f}")
        print(f"Jump Factor Used:    {res['k_stride']}")
        print(f"Denominator (k^4-1): {res['k_stride']**4 - 1}")
        print(f"Estimated Error:     {res['Error_Est']:.8f}")
        print(f"Improved Integral:   {res['I_improved']:.8f}")
    else:
        print(f"Note: {res['Note']}")
else:
    print(f"Calculation Failed: {res['Note']}")
# Out:
# --- Final Results ---
# Integral (I_h):      120.484858
# Coarse Integral (I_kh): 120.484819
# Jump Factor Used:    2
# Denominator (k^4-1): 15
# Estimated Error:     0.00000264
# Improved Integral:   120.48486103
