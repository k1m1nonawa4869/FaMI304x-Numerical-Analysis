# %%
import numpy as np
import pandas as pd
import math
import os

# Set display options
pd.set_option('display.precision', 6)
pd.set_option('display.width', 1000)

# %%
def get_m2_max_abs_second_derivative(func_d2, a, b, num_samples=1000):
    """
    Estimates M2 = max|f''(x)| on [a, b] by sampling.
    """
    x_test = np.linspace(a, b, num_samples)
    y_test = np.abs(func_d2(x_test))
    return np.max(y_test)

# %% [markdown]
# # Trapezoid-Join in Approximate Definite Integral

# %% [markdown]
# ## Algorithm

# %% [markdown]
# * Input
# 1.  **Function**: $f(x)$ defined and continuous on $[a, b]$.
# 2.  **Interval**: $[a, b]$.
# 3.  **Error Tolerance**: $\epsilon$ (maximum allowable error).
#
# * Steps
#
# **1. Determine Number of Sub-intervals ($n$)**
#    * Calculate the maximum absolute value of the second derivative on the interval:
#        $$M_2 = \max_{x \in [a,b]} |f''(x)|$$
#    * Using the error bound formula $|E| \le \frac{M_2 (b-a)^3}{12 n^2}$, solve for the minimum integer $n$ such that the error is less than $\epsilon$:
#        $$n > \sqrt{\frac{M_2 (b-a)^3}{12 \epsilon}}$$
#    * Set $n = \lceil \text{calculated value} \rceil$ (round up to the nearest integer).
#
# **2. Define Step Size ($h$)**
#    * Calculate the width of each sub-interval:
#        $$h = \frac{b - a}{n}$$
#
# **3. Discretization**
#    * Generate $n+1$ points ($x_k$) and their corresponding function values ($y_k$):
#        For $k = 0, 1, \dots, n$:
#        $$x_k = a + k \cdot h$$
#        $$y_k = f(x_k)$$
#
# **4. Compute Integral Approximation**
#    * Apply the Composite Trapezoidal formula:
#        $$I \approx \frac{h}{2} \left[ y_0 + y_n + 2 \sum_{k=1}^{n-1} y_k \right]$$
#
# ## Output
# * **Approximate Integral**: $I \approx \int_a^b f(x) \, dx$

# %%
def loopTimes (f, d2f, a, b, eps):
    # Step 1: Calculate M2
    M2 = get_m2_max_abs_second_derivative(d2f, a, b)

    # Step 2: Determine number of segments n
    # Error <= (M2 * (b-a)^3) / (12 * n^2) < eps
    # n > sqrt( (M2 * (b-a)^3) / (12 * eps) )
    numerator = M2 * (b - a)**3
    denominator = 12 * eps
    n_float = np.sqrt(numerator / denominator)
    n = math.ceil(n_float)

    return numerator, denominator, n_float, n

# %%
def solve_trapezoidal(f, d2f, a, b, eps):
    M2 = get_m2_max_abs_second_derivative(d2f, a, b)
    numerator, denominator, n_float, n = loopTimes(f, d2f, a, b, eps)
    h = (b - a) / n

    # Step 4: Generate points x_k and values y_k
    # x points
    x_values = np.linspace(a, b, n + 1)
    # y points
    y_values = f(x_values)

    # Display Table using Pandas
    data = {
        'k': range(n + 1),
        'x_k': x_values,
        'y_k': y_values
    }
    df = pd.DataFrame(data)

    # Step 5: Apply Trapezoidal Formula
    # I = h/2 * [y0 + yn + 2 * sum(y_1 to y_{n-1})]
    sum_middle = np.sum(y_values[1:-1])
    y_start = y_values[0]
    y_end = y_values[-1]
    
    I = (h / 2) * (y_start + y_end + 2 * sum_middle)
    
    return df, I

# %% [markdown]
# ## Result

# %%
f = lambda x: 1/(x**2+1)

d2f = lambda x: (2*(3*x**2-1))/(x**6+3*x**4+3*x**2+1)

a = 0.0       # Start of interval
b = 2.0       # End of interval
eps = 1e-6 # Desired maximum error

print(f"--- Trapezoidal Rule Calculation ---")
print(f"Goal: Integrate f(x) on [{a}, {b}] with error < {eps}\n")
# Out:
# --- Trapezoidal Rule Calculation ---
# Goal: Integrate f(x) on [0.0, 2.0] with error < 1e-06

# %%
M2 = get_m2_max_abs_second_derivative(d2f, a, b)
print(f"Step 1: Estimate max|f''(x)| (M2)")
print(f"M2 ≈ {M2:.6f}")
# Out:
# Step 1: Estimate max|f''(x)| (M2)
# M2 ≈ 2.000000

# %%
numerator, denominator, n_float, n = loopTimes(f, d2f, a, b, eps)
print(f"\nStep 2: Calculate minimum n")
print(f"n > sqrt({numerator:.6f} / {denominator:.6f}) = {n_float:.6f}")
print(f"Chosen n = {n}")
# Out:
# Step 2: Calculate minimum n
# n > sqrt(16.000000 / 0.000012) = 1154.700538
# Chosen n = 1155

# %%
h = (b - a) / n
print(f"\nStep 3: Calculate step size h")
print(f"h = ({b} - {a}) / {n} = {h:.6f}")
# Out:
# Step 3: Calculate step size h
# h = (2.0 - 0.0) / 1155 = 0.001732

# %%
df, I = solve_trapezoidal(f, d2f, a, b, eps)
print(f"\nStep 4: Table of values (x_k, y_k)")
df
# Out:
# Step 4: Table of values (x_k, y_k)
#          k       x_k       y_k
# 0        0  0.000000  1.000000
# 1        1  0.001732  0.999997
# 2        2  0.003463  0.999988
# 3        3  0.005195  0.999973
# 4        4  0.006926  0.999952
# ...    ...       ...       ...
# 1151  1151  1.993074  0.201112
# 1152  1152  1.994805  0.200834
# 1153  1153  1.996537  0.200555
# 1154  1154  1.998268  0.200277
# 1155  1155  2.000000  0.200000
#
# [1156 rows x 3 columns]

# %%
print(f"\nStep 5: Final Calculation")
print(f"Approximate Integral I = {I:.8f}")
# Out:
# Step 5: Final Calculation
# Approximate Integral I = 1.10714868

# %% [markdown]
# # Runga-Principle estimate

# %% [markdown]
# ## Algorithm

# %% [markdown]
# - Objective
# Calculate $I = \int_{a}^{b} f(x) \, dx$ to a desired accuracy $\epsilon$.
#
# - Initialization
#
#     1.  **Start with the coarsest grid**:
#         * Number of intervals: $n = 1$.
#         * Step size: $h = b - a$.
#     2.  **Calculate Initial Integral ($I_{loose}$)**:
#         $$I_{loose} = \frac{h}{2} [f(a) + f(b)]$$
#
# - Iteration Loop
#     Repeat the following steps until convergence:
#
#     1.  **Refine the Grid**:
#         * Double the number of intervals: $n_{new} = 2 \times n$.
#         * Halve the step size: $h_{new} = h / 2$.
#
#     2.  **Calculate New Points**:
#         * Generate the new midpoints $x_{new}$ for the refined grid.
#         * Calculate sum of function values at these new points: $S_{new} = \sum f(x_{new})$.
#
#     3.  **Compute New Integral ($I_{dense}$)**:
#         * Use the recursive property of the Trapezoidal rule to avoid recalculating old points:
#             $$I_{dense} = \frac{I_{loose}}{2} + h_{new} \times S_{new}$$
#
#     4.  **Estimate Error (Runge's Principle)**:
#         * For Trapezoidal Rule (Order $p=2$), the divisor is $2^2 - 1 = 3$.
#         * $$E \approx \frac{|I_{dense} - I_{loose}|}{3}$$
#
#     5.  **Check Convergence**:
#         * **If** $E < \epsilon$:
#             * **Stop**.
#             * **Result**: $I_{final} = I_{dense} + E$ (Richardson Improvement).
#         * **Else**:
#             * Update for next iteration: $I_{loose} \leftarrow I_{dense}$, $h \leftarrow h_{new}$, $n \leftarrow n_{new}$.
#             * Repeat loop.

# %%
def solve_adaptive_trapezoid_runge(f, a, b, eps):
    """
    Adaptive Trapezoidal Rule using Runge's Principle for termination.
    
    Args:
        f (function): Function to integrate.
        a (float): Start of interval.
        b (float): End of interval.
        eps (float): Error tolerance.
        
    Returns:
        float: Approximate Integral.
        pd.DataFrame: History of iterations.
    """
    # List to store history for the table
    history = []
    
    # --- Step 1: Initialization (Loose Grid: n=1) ---
    n_loose = 1
    h_loose = b - a
    
    # I_loose = h/2 * (f(a) + f(b))
    I_loose = (h_loose / 2) * (f(a) + f(b))
    
    history.append({
        'Iteration': 0,
        'n': n_loose,
        'h': h_loose,
        'Integral': I_loose,
        'Error Est': np.nan # No error estimate for the first step
    })
    
    iteration = 1
    
    print(f"Start: n={n_loose}, I={I_loose:.6f}")
    
    # --- Step 2: Loop (Dense Grid Refinement) ---
    while True:
        # 2a. Shrink step h to 1/2 original (Dense Grid)
        n_dense = n_loose * 2
        h_dense = h_loose / 2
        
        # 2b. Calculate I_dense
        # OPTIMIZATION: Instead of re-summing everything, we just add the new midpoints.
        # The new points are at indices 1, 3, 5... relative to the new grid.
        # x_new = a + (2k - 1) * h_dense
        
        # Generate only the NEW odd points
        k_values = np.arange(1, n_loose + 1) # 1, 2, ..., n_loose
        x_new_points = a + (2 * k_values - 1) * h_dense
        sum_new_points = np.sum(f(x_new_points))
        
        # Recursive Trapezoid Formula: I_new = I_old/2 + h_new * sum(new_points)
        I_dense = (I_loose / 2) + (h_dense * sum_new_points)
        
        # 2c. Calculate Error using Runge's Principle (p=2 -> Divisor 3)
        error_est = abs(I_dense - I_loose) / 3.0
        
        # Log history
        history.append({
            'Iteration': iteration,
            'n': n_dense,
            'h': h_dense,
            'Integral': I_dense,
            'Error Est': error_est
        })
        
        # 2d. Check Condition
        if error_est < eps:
            print(f"Stop: Converged at Iteration {iteration} (Error {error_est:.2e} < {eps})")
            
            # Richardson Improvement
            I_improved = I_dense + error_est
            
            return I_improved, pd.DataFrame(history)
        
        # Prepare for next loop: Dense becomes the new Loose
        n_loose = n_dense
        h_loose = h_dense
        I_loose = I_dense
        iteration += 1
        
        # Safety break to prevent infinite loops if function behaves badly
        if iteration > 25: 
            print("Warning: Max iterations reached without convergence.")
            return I_dense, pd.DataFrame(history)

# %% [markdown]
# ## Result

# %%
# --- EXAMPLE USAGE ---

# Function: f(x) = 1 / (x^2 + 1)
# Exact Integral from 0 to 2 is arctan(2) ≈ 1.10714872
f_func = lambda x: 1 / (x**2 + 1)
a_val = 0.0
b_val = 2.0
epsilon = 1e-6

# %%
print(f"--- Adaptive Trapezoid (Runge Method) ---")
print(f"Goal: Integrate 1/(x^2+1) on [0, 2] with eps < {epsilon}\n")

final_I, df_history = solve_adaptive_trapezoid_runge(f_func, a_val, b_val, epsilon)

print("\n--- Iteration History ---")
df_history
# Out:
# --- Adaptive Trapezoid (Runge Method) ---
# Goal: Integrate 1/(x^2+1) on [0, 2] with eps < 1e-06
#
# Start: n=1, I=1.200000
# Stop: Converged at Iteration 8 (Error 8.14e-07 < 1e-06)
#
# --- Iteration History ---
#    Iteration    n         h  Integral     Error Est
# 0          0    1  2.000000  1.200000           NaN
# 1          1    2  1.000000  1.100000  3.333333e-02
# 2          2    4  0.500000  1.103846  1.282051e-03
# 3          3    8  0.250000  1.106317  8.234926e-04
# 4          4   16  0.125000  1.106940  2.079436e-04
# 5          5   32  0.062500  1.107097  5.205893e-05
# 6          6   64  0.031250  1.107136  1.301931e-05
# 7          7  128  0.015625  1.107145  3.255113e-06
# 8          8  256  0.007812  1.107148  8.137961e-07

# %%
print("\n--- Final Result ---")
print(f"Approximate Integral (Richardson Improved): {final_I:.9f}")
# Out:
# --- Final Result ---
# Approximate Integral (Richardson Improved): 1.107148718
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # No-function variant

# %% [markdown]
# ## Algorithm

# %% [markdown]
# 1. Problem Statement
# Calculate the definite integral $I = \int_{a}^{b} g(x, f(x)) \, dx$ given only a discrete set of data points for $f(x)$:
# $$D = \{(x_0, y_0), (x_1, y_1), \dots, (x_n, y_n)\}$$
# where $y_i = f(x_i)$.
#
# 2. Inputs
#     1.  **Data Points**: A list of $n+1$ tuples $(x_i, y_i)$.
#     2.  **Transformation Function**: A function $g(x, y)$ that defines the integrand.
#     3.  **Integration Method Order ($p$)**:
#     * $p=2$ for Trapezoidal Rule.
#     * $p=4$ for Simpson's Rule.
#
# 3. Algorithm Steps
#
# - Step 1: Data Transformation
#
# Construct the transformed dataset $Z$ representing the actual values to be integrated.
# For each point $(x_i, y_i)$ in the input:
# $$z_i = g(x_i, y_i)$$
# Resulting dataset: $\{(x_0, z_0), (x_1, z_1), \dots, (x_n, z_n)\}$.
#
# - Step 2: Determine Stride Factor ($k$)
#
#     Find the smallest integer $k > 1$ such that the number of intervals $n$ is divisible by $k$.
#     1.  Calculate $n = \text{total points} - 1$.
#     2.  Iterate $k$ from 2 up to $\sqrt{n}$:
#     * If $n \pmod k == 0$, select this $k$ and proceed.
#     3.  If no divisor is found, $n$ is prime. The method cannot be applied (unless $k=n$).
#
# - Step 3: Calculate Fine Integral ($I_h$)
# Compute the integral using the **full dataset** (step size $h$) with the chosen integration rule (e.g., Trapezoidal).
# $$I_h \approx \text{Integrate}(\{(x_0, z_0), (x_1, z_1), \dots, (x_n, z_n)\})$$
#
# - Step 4: Calculate Coarse Integral ($I_{kh}$)
# Compute the integral using a **subset of the data** created by taking every $k$-th point (step size $k \cdot h$).
# $$I_{kh} \approx \text{Integrate}(\{(x_0, z_0), (x_k, z_k), (x_{2k}, z_{2k}), \dots, (x_n, z_n)\})$$
#
# - Step 5: Error Estimation & Correction
#     Apply Generalized Runge's Principle to estimate the error and improve the result.
#
#     1.  **Calculate Denominator**:
#     $$D = k^p - 1$$
#     *(e.g., for Trapezoid ($p=2$) and $k=3$, $D = 3^2 - 1 = 8$)*
#
#     2.  **Estimate Error**:
#     $$E \approx \frac{|I_h - I_{kh}|}{D}$$
#
#     3.  **Compute Improved Result** (Richardson Extrapolation):
#     $$I_{\text{optimal}} = I_h + \frac{I_h - I_{kh}}{D}$$
#
# 4. Output
#     * **Approximate Integral**: $I_{\text{optimal}}$
#     * **Estimated Error**: $E$

# %%
def trapezoidal_rule_data(x, y):
    """ Helper: Standard Trapezoid calculation """
    n = len(x) - 1
    if n == 0: return 0.0
    h = (x[-1] - x[0]) / n
    return (h / 2) * (y[0] + y[-1] + 2 * np.sum(y[1:-1]))

# %%
def solve_runge_general(x_vals, y_vals, k_stride=None):
    """
    Calculates Integral using Generalized Runge's Principle.
    Allows for arbitrary step jumps (k=2, 3, etc.)
    
    Args:
        x_vals, y_vals: Data points.
        k_stride (int): The jump factor. If None, tries to find valid k (2 or 3).
    """
    x = np.array(x_vals)
    y = np.array(y_vals)
    n = len(x) - 1  # Number of intervals
    
    # Auto-detect stride if not provided
    if k_stride is None:
        # Find the smallest divisor (lowest GCD > 1)
        found_k = False
        
        # We search from 2 up to sqrt(n). 
        # If no divisor is found in this range, n is prime.
        k_stride = 0
        limit = int(n**0.5) + 1
        for i in range(2, limit + 1):
            if n % i == 0:
                k_stride = i
                found_k = True
                break
        
        # Handle Prime Cases (where lowest divisor is n itself)
        # Note: If n=2 or n=3, they are technically prime, but k=n (1 coarse interval) is often valid.
        # However, per your request, we strictly "Exit if prime".
        if not found_k:
            # If n is prime, the only divisor is n itself.
            # Example: n=2 (k=2), n=3 (k=3), n=5 (k=5).
            # If you specifically want to ERROR on primes (including 2, 3, 5, 7...):
            raise ValueError(f"Number of intervals n={n} is prime. Cannot find a strictly smaller stride factor.")
            
            # OPTIONAL: If you want to allow n=2 or n=3 (which work fine as single-step coarse grids), 
            # you could use: k_stride = n 

    # Validation check (redundant if logic above works, but good for safety)
    if n % k_stride != 0:
        raise ValueError(f"Number of intervals n={n} is not divisible by jump factor k={k_stride}")
                                                                                        
    # 1. Fine Grid (I_h) - Use all points
    I_h = trapezoidal_rule_data(x, y)
    
    # 2. Coarse Grid (I_kh) - Use every k-th point
    # Slice syntax [::k] takes every k-th element
    x_coarse = x[::k_stride]
    y_coarse = y[::k_stride]
    
    I_kh = trapezoidal_rule_data(x_coarse, y_coarse)
    
    # 3. Generalized Error Formula
    # p = 2 for Trapezoid
    p = 2
    denominator = (k_stride ** p) - 1  # e.g., 3^2 - 1 = 8
    
    error_est = abs(I_h - I_kh) / denominator
    I_improved = I_h + (I_h - I_kh) / denominator
    
    return {
        "n_intervals": n,
        "k_stride": k_stride,
        "denominator": denominator,
        "I_h": I_h,
        "I_kh": I_kh,
        "Error_Est": error_est,
        "I_improved": I_improved
    }

# %%
# --- 3. Main Function: Accepts List of (x, y) Tuples ---

def solve_functional_integral_tuples(points_list, functional_func):
    """
    Integrates g(f(x)) given a list of points [(x, f(x)), ...].
    
    Args:
        points_list: List of tuples, e.g., [(1.0, 1.0), (1.1, 1.21), ...]
        functional_func: Lambda function (x, y) -> new_y
    """
    # Unzip the list of tuples into two separate lists
    # zip(*[(x1,y1), (x2,y2)]) -> (x1, x2), (y1, y2)
    x_vals, y_vals = zip(*points_list)
    
    # Convert to Numpy Arrays for calculation
    x = np.array(x_vals)
    y_original = np.array(y_vals)
    
    # Apply Transformation: g(x, f(x))
    try:
        y_transformed = functional_func(x, y_original)
    except:
        y_transformed = np.array([functional_func(xi, yi) for xi, yi in zip(x, y_original)])
    
    print(f"--- Processing {len(points_list)} points ---")
    df = pd.DataFrame({
        'x': x,
        'Original f(x)': y_original,
        'Transformed g(x, f(x))': y_transformed
    })
    
    # Solve
    result = solve_runge_general(x, y_transformed)
    return df, result

# %% [markdown]
# ## Result

# %%
#Reading file

def parse_xy_data(filepath, delimiter=None):
    """
    Reads a CSV-like file with x, y data and returns a list of (x, y) tuples.

    This function is designed to handle different delimiters (like ';' or ' ')
    and assumes that commas (',') are used as decimal separators, based on
    the provided image.

    Args:
        filepath (str): The path to the data file.
        delimiter (str, optional): The column delimiter (e.g., ';', ' '). 
                                   If None, the function will try to 
                                   auto-detect it.

    Returns:
        list: A list of (x, y) float tuples.
              Returns an empty list if the file cannot be read or is empty.
    """
    data_points = []
    detected_delimiter = delimiter
    
    # --- 1. Delimiter Sniffing (if not provided) ---
    if detected_delimiter is None:
        try:
            with open(filepath, 'r', encoding='utf-8') as f:
                # Read the first non-empty line to guess
                first_line = ""
                for line in f:
                    first_line = line.strip()
                    if first_line:
                        break
                
                if ';' in first_line:
                    detected_delimiter = ';'
                elif ' ' in first_line:
                    # Check if it's likely a space delimiter
                    parts = re.split(r'\s+', first_line)
                    if len(parts) == 2:
                        try:
                            # Try to parse to see if it makes sense
                            float(parts[0].replace(',', '.'))
                            float(parts[1].replace(',', '.'))
                            detected_delimiter = ' '
                        except (ValueError, IndexError):
                             # Not a valid 2-column space-delimited float line
                             pass
                
                if detected_delimiter is None and ',' in first_line:
                    # Comma is the last guess, as it's ambiguous with decimal
                    detected_delimiter = ','
                
                if detected_delimiter is None:
                    # Final fallback based on your image
                    print("Warning: Could not auto-detect delimiter. Falling back to ';'.")
                    detected_delimiter = ';'
        except Exception as e:
            print(f"Error opening/reading file for sniffing: {e}")
            return [] # Return empty list on error
    
    print(f"Using delimiter: '{detected_delimiter}'")

    # --- 2. File Parsing ---
    try:
        with open(filepath, 'r', encoding='utf-8') as f:
            for line_number, line in enumerate(f, 1):
                line = line.strip()
                if not line or line.startswith('#'):
                    continue # Skip empty lines or comment lines

                # Split the line by the detected delimiter
                if detected_delimiter == ' ':
                    # Use regex split for spaces to handle multiple spaces
                    parts = re.split(r'\s+', line)
                else:
                    parts = line.split(detected_delimiter)

                # Ensure we have exactly two columns
                if len(parts) == 2:
                    x_str, y_str = parts
                    
                    try:
                        # KEY STEP: Replace comma with dot for float conversion
                        x_val = float(x_str.strip().replace(',', '.'))
                        y_val = float(y_str.strip().replace(',', '.'))
                        data_points.append((x_val, y_val))
                    except ValueError as e:
                        # Warn if conversion to float fails
                        print(f"Warning: Could not parse numbers on line {line_number}: '{line}'. Error: {e}")
                else:
                    # Warn if the line doesn't have exactly two parts
                    print(f"Warning: Skipping malformed line {line_number}: '{line}'. Expected 2 columns, found {len(parts)}")
    
    except FileNotFoundError:
        print(f"Error: File not found at '{filepath}'")
        return []
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
        return []

    return data_points

# %%
print("--- Example: Reading '19data.csv' ---")
    
# You would replace '19data.csv' with the path to your actual file
file_to_read = '19data.csv' 
    
# Check if the file exists before trying to read it
if os.path.exists(file_to_read):
    # Call the function to parse the file.
    # It will try to auto-detect the delimiter.
    all_points = parse_xy_data(file_to_read)
        
    if all_points:
        print(f"Successfully parsed {len(all_points)} data points:")
        df_input = pd.DataFrame(all_points, columns=['x', 'y'])
        print(df_input.to_string(index=False))
    else:
        print(f"Could not parse any data points from '{file_to_read}'.")
        print("Please check the file format and warnings above.")
            
else:
    print(f"Error: The file '{file_to_read}' was not found.")
    print("Please create this file or change 'file_to_read' variable")
    print("to point to your existing data file.")
# Out:
# --- Example: Reading '19data.csv' ---
# Using delimiter: ';'
# Successfully parsed 141 data points:
#    x         y
#  1.0  1.888165
#  1.1  2.040674
#  1.2  2.183783
#  1.3  2.317062
#  1.4  2.440180
#  1.5  2.552904
#  1.6  2.655108
#  1.7  2.746770
#  1.8  2.827973
#  1.9  2.898905
#  2.0  2.959856
#  2.1  3.011216
#  2.2  3.053472
#  2.3  3.087200
#  2.4  3.113063
#  2.5  3.131801
#  2.6  3.144226
#  2.7  3.151214
#  2.8  3.153693
#  2.9  3.152638
#  3.0  3.149059
#  3.1  3.143991
#  3.2  3.138483
#  3.3  3.133589
#  3.4  3.130359
#  3.5  3.129822
#  3.6  3.132985
#  3.7  3.140813
#  3.8  3.154229
#  3.9  3.174097
#  4.0  3.201218
#  4.1  3.236321
#  4.2  3.280052
#  4.3  3.332976
#  4.4  3.395562
#  4.5  3.468184
#  4.6  3.551115
#  4.7  3.644527
#  4.8  3.748484
#  4.9  3.862948
#  5.0  3.987774
#  5.1  4.122713
#  5.2  4.267418
#  5.3  4.421440
#  5.4  4.584241
#  5.5  4.755192
#  5.6  4.933585
#  5.7  5.118637
#  5.8  5.309498
#  5.9  5.505260
#  6.0  5.704965
# ...

# %%
# 1. Prepare Data as List of Tuples
# Imagine this comes from reading a file row by row
subset_points = [
        (x, y) for (x, y) in all_points 
        if 1 <= x <= 7
]

# 2. Define Function g(x, f(x))
# Example: Integrate x * f(x) + sqrt(x)
my_func = lambda x, y: x * y + np.sqrt(x)

# %%
# 3. Calculate
df, res = solve_functional_integral_tuples(subset_points, my_func)
df
# Out:
# --- Processing 61 points ---
#       x  Original f(x)  Transformed g(x, f(x))
# 0   1.0       1.888165                2.888165
# 1   1.1       2.040674                3.293550
# 2   1.2       2.183783                3.715984
# 3   1.3       2.317062                4.152357
# 4   1.4       2.440180                4.599468
# ..  ...            ...                     ...
# 56  6.6       6.928754               48.298824
# 57  6.7       7.127250               50.341011
# 58  6.8       7.321477               52.393726
# 59  6.9       7.510494               54.449192
# 60  7.0       7.693410               56.499625
#
# [61 rows x 3 columns]

# %%
print("\n--- Final Results ---")
print(f"Integral (I_h):      {res['I_h']:.6f}")
print(f"Coarse Integral (I_kh): {res['I_kh']:.6f}")
print(f"Improved Integral:   {res['I_improved']:.6f}")
print(f"Denominator (k^2-1): {res['k_stride']**2 - 1}")
print(f"Estimated Error:     {res['Error_Est']:.8f}")
print(f"Jump Factor Used:    {res['k_stride']}")
# Out:
# --- Final Results ---
# Integral (I_h):      120.498607
# Coarse Integral (I_kh): 120.539855
# Improved Integral:   120.484858
# Denominator (k^2-1): 3
# Estimated Error:     0.01374908
# Jump Factor Used:    2
